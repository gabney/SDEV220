# %% [markdown]
# ## Module 01 Programming Assignment - Numbers and Types
# SDEV 220 - Software Development Using Python \
# Gabriel Abney

# %% [markdown]
# ### 3.1
# How many seconds are in an hour? Use the interactive interpreter as a calculator and multiply the number of seconds in a minute (60) by the number of minutes in an hour (also 60).

# %%
seconds_in_minute = 60
minutes_in_hour = 60
print(seconds_in_minute*minutes_in_hour)
# Out:
# 3600

# %% [markdown]
# ### 3.2
# Assign the result from the previous task (seconds in an hour) to a variable called seconds_per_hour.

# %%
seconds_per_hour = seconds_in_minute * minutes_in_hour
print(seconds_per_hour)
# Out:
# 3600

# %% [markdown]
# ### 3.3
# How many seconds are in a day? Use your seconds_per_hour variable.

# %%
hours_in_day = 24
print(seconds_per_hour * hours_in_day)
# Out:
# 86400

# %% [markdown]
# ### 3.4
# Calculate seconds per day again, but this time save the result in a variable called seconds_per_day.

# %%
seconds_per_day = seconds_per_hour * hours_in_day
print(seconds_per_day)
# Out:
# 86400

# %% [markdown]
# ### 3.5
# Divide seconds_per_day by seconds_per_hour. Use floating-point (/) division.

# %%
floating_point_division = seconds_per_day / seconds_per_hour
print(floating_point_division)
# Out:
# 24.0

# %% [markdown]
# ### 3.6
# Divide seconds_per_day by seconds_per_hour, using integer (//) division. Did this number agree with the floating-point value from the previous question, aside from the final .0?

# %%
integer_division = seconds_per_day // seconds_per_hour
print(integer_division)

equivalency_check = floating_point_division == integer_division
print(f"Are the values equivalent? {equivalency_check}")
# Out:
# 24
# Are the values equivalent? True
