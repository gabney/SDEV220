# %% [markdown]
# ## Module 04 Programming Assignment - Modules and Databases
# SDEV 220 - Software Development Using Python\
# Gabriel Abney

# %% [markdown]
# ### 11.1

# %% [markdown]
# ### 11.2

# %% [markdown]
# ### 16.8
